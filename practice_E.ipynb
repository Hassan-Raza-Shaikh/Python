# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("e.csv")
df
# Out:
#     student_id age  gender study_hours_per_week  attendance_percent  \
# 0         1001  20    Male                   15                85.0
# 1         1002  21  Female                    ?                90.0
# 2         1003  19    male                   12                75.0
# 3         1004  22  FEMALE                    8                60.0
# 4         1005  20       M                   20                95.0
# 5         1006   ?  Female                    5                50.0
# 6         1007  23    male                   18                88.0
# 7         1008  21  Female                   10                 NaN
# 8         1009  20  female                   16                80.0
# 9         1010  19    Male                    0                45.0
# 10        1011  22  Female                   25               110.0
# 11        1012  24    Male                   30                85.0
# 12        1013  20  Female                   14                78.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     student_id age  gender study_hours_per_week  attendance_percent  \
# 0         1001  20    Male                   15                85.0
# 1         1002  21  Female                    ?                90.0
# 2         1003  19    male                   12                75.0
# 3         1004  22  FEMALE                    8                60.0
# 4         1005  20       M                   20                95.0
# 5         1006   ?  Female                    5                50.0
# 6         1007  23    male                   18                88.0
# 7         1008  21  Female                   10                 NaN
# 8         1009  20  female                   16                80.0
# 9         1010  19    Male                    0                45.0
# 10        1011  22  Female                   25               110.0
# 11        1012  24    Male                   30                85.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     30 non-null     int64
#  1   age                            30 non-null     str
#  2   gender                         30 non-null     str
#  3   study_hours_per_week           29 non-null     str
#  4   attendance_percent             29 non-null     float64
#  5   parent_education               30 non-null     str
#  6   previous_gpa                   29 non-null     str
#  7   internet_access                30 non-null     str
#  8   extracurricular_participation  30 non-null     str
#  9   sleep_hours_per_night          30 non-null     str
#  10  mental_stress_level            30 non-null     str
#  11  final_exam_score               30 non-null     int64
#  12  pass                           30 non-null     int64
# ...

# %%
df.shape
# Out:
# (30, 13)

# %%
df.isnull().count()
# Out:
# student_id                       30
# age                              30
# gender                           30
# study_hours_per_week             30
# attendance_percent               30
# parent_education                 30
# previous_gpa                     30
# internet_access                  30
# extracurricular_participation    30
# sleep_hours_per_night            30
# mental_stress_level              30
# final_exam_score                 30
# pass                             30
# dtype: int64

# %%
df.duplicated().count()
# Out:
# np.int64(30)

# %%
df['study_hours_per_week']=df['study_hours_per_week'].replace('?' , 'NaN')

# %%
df['gender']=df['gender'].replace('FEMALE ', 'Female')
df['gender']=df['gender'].replace('female' , 'Female')
df['gender']=df['gender'].replace('male' , 'Male')

# %%
df['gender']=df['gender'].map({'Female': 1 , 'Male' : 0})

# %%
df['previous_gpa']=df['previous_gpa'].replace('?', 'NaN')
df['internet_access']=df['internet_access'].map({'Yes':1 , 'No':0})

# %%
df['extracurricular_participation']=df['extracurricular_participation'].replace('?', 'NaN')
df['extracurricular_participation']=df['extracurricular_participation'].map({'Yes':1 , 'No':0})

# %%
df
# Out:
#     student_id age  gender study_hours_per_week  attendance_percent  \
# 0         1001  20     0.0                   15                85.0
# 1         1002  21     1.0                  NaN                90.0
# 2         1003  19     0.0                   12                75.0
# 3         1004  22     NaN                    8                60.0
# 4         1005  20     NaN                   20                95.0
# 5         1006   ?     1.0                    5                50.0
# 6         1007  23     0.0                   18                88.0
# 7         1008  21     1.0                   10                 NaN
# 8         1009  20     1.0                   16                80.0
# 9         1010  19     0.0                    0                45.0
# 10        1011  22     1.0                   25               110.0
# 11        1012  24     0.0                   30                85.0
# 12        1013  20     1.0                   14                78.0
# ...

# %%
df['sleep_hours_per_night']=df['sleep_hours_per_night'].replace('?', 'NaN')

# %%
df['age']=df['age'].replace('?', 'NaN')

# %%
df
# Out:
#     student_id  age  gender study_hours_per_week  attendance_percent  \
# 0         1001   20     0.0                   15                85.0
# 1         1002   21     1.0                  NaN                90.0
# 2         1003   19     0.0                   12                75.0
# 3         1004   22     NaN                    8                60.0
# 4         1005   20     NaN                   20                95.0
# 5         1006  NaN     1.0                    5                50.0
# 6         1007   23     0.0                   18                88.0
# 7         1008   21     1.0                   10                 NaN
# 8         1009   20     1.0                   16                80.0
# 9         1010   19     0.0                    0                45.0
# 10        1011   22     1.0                   25               110.0
# 11        1012   24     0.0                   30                85.0
# 12        1013   20     1.0                   14                78.0
# ...

# %%
df['mental_stress_level']=df['mental_stress_level'].map({'Low':1 , 'Medium':2 , 'High':3})

# %%
df
# Out:
#     student_id  age  gender study_hours_per_week  attendance_percent  \
# 0         1001   20     0.0                   15                85.0
# 1         1002   21     1.0                  NaN                90.0
# 2         1003   19     0.0                   12                75.0
# 3         1004   22     NaN                    8                60.0
# 4         1005   20     NaN                   20                95.0
# 5         1006  NaN     1.0                    5                50.0
# 6         1007   23     0.0                   18                88.0
# 7         1008   21     1.0                   10                 NaN
# 8         1009   20     1.0                   16                80.0
# 9         1010   19     0.0                    0                45.0
# 10        1011   22     1.0                   25               110.0
# 11        1012   24     0.0                   30                85.0
# 12        1013   20     1.0                   14                78.0
# ...

# %%
df
# Out:
#     student_id  age  gender study_hours_per_week  attendance_percent  \
# 0         1001   20     0.0                   15                85.0
# 1         1002   21     1.0                  NaN                90.0
# 2         1003   19     0.0                   12                75.0
# 3         1004   22     NaN                    8                60.0
# 4         1005   20     NaN                   20                95.0
# 5         1006  NaN     1.0                    5                50.0
# 6         1007   23     0.0                   18                88.0
# 7         1008   21     1.0                   10                 NaN
# 8         1009   20     1.0                   16                80.0
# 9         1010   19     0.0                    0                45.0
# 10        1011   22     1.0                   25               110.0
# 11        1012   24     0.0                   30                85.0
# 12        1013   20     1.0                   14                78.0
# ...

# %%
df=df.replace('NaN' , np.nan)

# %%
df=df.dropna()

# %%
print(df)
# Out:
#     student_id age  gender study_hours_per_week  attendance_percent  \
# 0         1001  20     0.0                   15                85.0
# 2         1003  19     0.0                   12                75.0
# 6         1007  23     0.0                   18                88.0
# 8         1009  20     1.0                   16                80.0
# 9         1010  19     0.0                    0                45.0
# 10        1011  22     1.0                   25               110.0
# 11        1012  24     0.0                   30                85.0
# 14        1015  22     1.0                    9                55.0
# 15        1016  23     0.0                   40                92.0
# 17        1018  20     0.0                   13                77.0
# 18        1019  21     1.0                   17                85.0
# 20        1021  23     1.0                    7                40.0
# 21        1022  20     0.0                   15                88.0
# ...

# %%
df
# Out:
#     student_id age  gender study_hours_per_week  attendance_percent  \
# 0         1001  20     0.0                   15                85.0
# 2         1003  19     0.0                   12                75.0
# 6         1007  23     0.0                   18                88.0
# 8         1009  20     1.0                   16                80.0
# 9         1010  19     0.0                    0                45.0
# 10        1011  22     1.0                   25               110.0
# 11        1012  24     0.0                   30                85.0
# 14        1015  22     1.0                    9                55.0
# 15        1016  23     0.0                   40                92.0
# 17        1018  20     0.0                   13                77.0
# 18        1019  21     1.0                   17                85.0
# 20        1021  23     1.0                    7                40.0
# 21        1022  20     0.0                   15                88.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     20 non-null     int64
#  1   age                            20 non-null     str
#  2   gender                         20 non-null     float64
#  3   study_hours_per_week           20 non-null     str
#  4   attendance_percent             20 non-null     float64
#  5   parent_education               20 non-null     str
#  6   previous_gpa                   20 non-null     str
#  7   internet_access                20 non-null     int64
#  8   extracurricular_participation  20 non-null     float64
#  9   sleep_hours_per_night          20 non-null     str
#  10  mental_stress_level            20 non-null     int64
#  11  final_exam_score               20 non-null     int64
#  12  pass                           20 non-null     int64
# ...

# %%
df['age']=df['age'].astype(int)
df['sleep_hours_per_night']=df['sleep_hours_per_night'].astype(int)
df['study_hours_per_week']=df['study_hours_per_week'].astype(int)
df['previous_gpa']=df['previous_gpa'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 20 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     20 non-null     int64
#  1   age                            20 non-null     int64
#  2   gender                         20 non-null     float64
#  3   study_hours_per_week           20 non-null     int64
#  4   attendance_percent             20 non-null     float64
#  5   parent_education               20 non-null     str
#  6   previous_gpa                   20 non-null     float64
#  7   internet_access                20 non-null     int64
#  8   extracurricular_participation  20 non-null     float64
#  9   sleep_hours_per_night          20 non-null     int64
#  10  mental_stress_level            20 non-null     int64
#  11  final_exam_score               20 non-null     int64
#  12  pass                           20 non-null     int64
# ...

# %%
df=df.drop('student_id' ,axis=1)
df=df.drop('parent_education' ,axis=1)

# %%
df
# Out:
#     age  gender  study_hours_per_week  attendance_percent  previous_gpa  \
# 0    20     0.0                    15                85.0           3.2
# 2    19     0.0                    12                75.0           2.9
# 6    23     0.0                    18                88.0           3.5
# 8    20     1.0                    16                80.0           3.3
# 9    19     0.0                     0                45.0           1.8
# 10   22     1.0                    25               110.0           4.0
# 11   24     0.0                    30                85.0           2.5
# 14   22     1.0                     9                55.0           2.0
# 15   23     0.0                    40                92.0           3.7
# 17   20     0.0                    13                77.0           2.8
# 18   21     1.0                    17                85.0           3.6
# 20   23     1.0                     7                40.0           1.9
# ...

# %%
plt.figure(figsize=(12,8))
for i , col in enumerate(df.columns):
    plt.subplot(4,5,i+1)
    plt.hist(df[col])
    plt.show()

# %%
sns.heatmap(df.corr() , annot=True)
# Out:
# <Axes: >

# %%
x=df[['age' ,'gender','study_hours_per_week','attendance_percent' ,'previous_gpa' ,'internet_access' ,'extracurricular_participation' ,'mental_stress_level' ]]
y=df['final_exam_score']
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train , x_test , y_train , y_test=train_test_split(x , y ,  test_size=0.2 , random_state=42)

# %%
lr=LinearRegression()
lr.fit(x_train, y_train)
y_pred=lr.predict(x_train)

# %%
y_pred
# Out:
# array([100.93163203, 108.63940325,  24.87096837,  78.99056245,
#         83.79390587,  31.5117964 ,  77.46317821,  88.94536782,
#         71.99056245,  42.69764226,  40.87953578,  86.17130323,
#         46.74552384,  77.98466161,  38.3039709 , 140.07998553])

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_train, y_pred))
print('MSE:', metrics.mean_squared_error(y_train, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred)))
# Out:
# MAE: 6.4817586597387695
# MSE: 52.57935154565665
# RMSE: 7.2511620824290395

# %%
x=df[['age' ,'gender','study_hours_per_week','attendance_percent' ,'previous_gpa' ,'internet_access' ,'extracurricular_participation' ,'mental_stress_level' ]]
y=df['pass']
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
x_train , x_test , y_train , y_test=train_test_split(x , y ,  test_size=0.2 , random_state=42)

# %%
lrr=LogisticRegression()
lrr.fit(x_train , y_train )
y_predd=lrr.predict(x_test)

# %%
var=metrics.confusion_matrix(y_test,y_predd)
var
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/sklearn/metrics/_classification.py:620: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# array([[4]])

# %%
var=metrics.accuracy_score(y_test,y_predd)
var
# Out:
# 1.0
