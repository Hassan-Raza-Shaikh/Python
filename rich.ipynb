# %%
pip install rich
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from rich.traceback import install
install()
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x10a97fb60>>

# %%
from rich.traceback import install
install()

a = 5
b = "hello"

print(a + b)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:7                                                                                    │
# │                                                                                                  │
# │   4 a = 5                                                                                        │
# │   5 b = "hello"                                                                                  │
# │   6                                                                                              │
# │ ❱ 7 print(a + b)                                                                                 │
# │   8                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
