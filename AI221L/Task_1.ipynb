# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('toy_dataset.csv')

# %%
data.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
x = data['Age'][:60]
y = data['Income'][:60]

# %%
print(x)
# Out:
# 0     41
# 1     54
# 2     42
# 3     40
# 4     46
# 5     36
# 6     32
# 7     39
# 8     51
# 9     30
# 10    48
# 11    47
# 12    46
# 13    42
# 14    61
# 15    43
# 16    27
# 17    38
# 18    47
# 19    35
# 20    57
# 21    33
# 22    33
# 23    27
# 24    58
# 25    64
# 26    58
# 27    44
# 28    34
# 29    45
# 30    44
# 31    39
# 32    55
# 33    27
# 34    63
# 35    41
# 36    64
# 37    41
# 38    61
# 39    59
# 40    26
# 41    41
# 42    47
# 43    58
# 44    33
# 45    30
# 46    51
# 47    45
# 48    38
# 49    56
# 50    55
# 51    42
# 52    58
# 53    57
# 54    32
# 55    55
# 56    62
# 57    43
# 58    35
# 59    31
# Name: Age, dtype: int64

# %%
print(y)
# Out:
# 0     40367.0
# 1     45084.0
# 2     52483.0
# 3     40941.0
# 4     50289.0
# 5     50786.0
# 6     33155.0
# 7     30914.0
# 8     68667.0
# 9     50082.0
# 10    41524.0
# 11    54777.0
# 12    62749.0
# 13    50894.0
# 14    38429.0
# 15    34074.0
# 16    50398.0
# 17    46373.0
# 18    51137.0
# 19    23688.0
# 20    17378.0
# 21    45919.0
# 22    23001.0
# 23    34292.0
# 24    55190.0
# 25    26169.0
# 26    57322.0
# 27    61704.0
# 28    53619.0
# 29    47421.0
# 30    40353.0
# 31    28125.0
# 32    42630.0
# 33    56645.0
# 34    41946.0
# 35    50312.0
# 36    47872.0
# 37    29538.0
# 38    39881.0
# 39    48518.0
# 40    16168.0
# 41    68522.0
# 42    50750.0
# 43    49614.0
# 44    56169.0
# 45    40661.0
# 46    53730.0
# 47    34613.0
# 48    35249.0
# 49    52218.0
# 50    47702.0
# 51    62512.0
# 52    48655.0
# 53    55133.0
# 54    39309.0
# 55    41036.0
# 56    60594.0
# 57    46373.0
# 58    53303.0
# 59    42281.0
# Name: Income, dtype: float64

# %%
scatter_plot = plt.scatter(x,y)
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Age vs Income Scatter Plot")
plt.show()

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
print("Mean of Age:", x_mean)
print("Mean of Income:", y_mean)
# Out:
# Mean of Age: 44.78333333333333
# Mean of Income: 45320.63333333333

# %%
slope_numerator = np.sum((x - x_mean) * (y - y_mean))
slope_denominator = np.sum((x - x_mean) ** 2)
m = slope_numerator / slope_denominator
c = y_mean - m * x_mean

# %%
print(f"Linear Regression Equation: Y = {m}X + {c}")
# Out:
# Linear Regression Equation: Y = 169.21569387856445X + 37742.59050913829

# %%
y_pred = m * x + c

# %%
print(y_pred)
# Out:
# 0     44680.433958
# 1     46880.237979
# 2     44849.649652
# 3     44511.218264
# 4     45526.512428
# 5     43834.355489
# 6     43157.492713
# 7     44342.002570
# 8     46372.590897
# 9     42819.061325
# 10    45864.943815
# 11    45695.728121
# 12    45526.512428
# 13    44849.649652
# 14    48064.747836
# 15    45018.865346
# 16    42311.414244
# 17    44172.786877
# 18    45695.728121
# 19    43665.139795
# 20    47387.885060
# 21    43326.708407
# 22    43326.708407
# 23    42311.414244
# 24    47557.100754
# 25    48572.394917
# 26    47557.100754
# 27    45188.081040
# 28    43495.924101
# 29    45357.296734
# 30    45188.081040
# 31    44342.002570
# 32    47049.453672
# 33    42311.414244
# 34    48403.179223
# 35    44680.433958
# 36    48572.394917
# 37    44680.433958
# 38    48064.747836
# 39    47726.316448
# 40    42142.198550
# 41    44680.433958
# 42    45695.728121
# 43    47557.100754
# 44    43326.708407
# 45    42819.061325
# 46    46372.590897
# ...

# %%
scatter_plot = plt.scatter(x,y)
line = plt.plot(x, y_pred, color='yellow')
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Age vs Income Scatter Plot")
plt.legend(['Regression Line', 'Data Points'])
plt.show()

# %%
error = y - y_pred
print("Error values:", error)
mse = np.mean(error ** 2)
print("Mean Squared Error:", mse)
# Out:
# Error values: 0     -4313.433958
# 1     -1796.237979
# 2      7633.350348
# 3     -3570.218264
# 4      4762.487572
# 5      6951.644511
# 6    -10002.492713
# 7    -13428.002570
# 8     22294.409103
# 9      7262.938675
# 10    -4340.943815
# 11     9081.271879
# 12    17222.487572
# 13     6044.350348
# 14    -9635.747836
# 15   -10944.865346
# 16     8086.585756
# 17     2200.213123
# 18     5441.271879
# 19   -19977.139795
# 20   -30009.885060
# 21     2592.291593
# 22   -20325.708407
# 23    -8019.414244
# 24     7632.899246
# 25   -22403.394917
# 26     9764.899246
# 27    16515.918960
# 28    10123.075899
# 29     2063.703266
# 30    -4835.081040
# 31   -16217.002570
# 32    -4419.453672
# 33    14333.585756
# 34    -6457.179223
# 35     5631.566042
# 36     -700.394917
# 37   -15142.433958
# 38    -8183.747836
# 39      791.683552
# 40   -25974.198550
# 41    23841.566042
# 42     5054.271879
# 43     2056.899246
# 44    12842.291593
# 45    -2158.061325
# ...

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
model = LinearRegression()
x_reshaped = x.values.reshape(-1, 1)
model.fit(x_reshaped, y)
y_sklearn_pred = model.predict(x_reshaped)
mse_sklearn = mean_squared_error(y, y_sklearn_pred)
print("Mean Squared Error (sklearn):", mse_sklearn)
# Out:
# Mean Squared Error (sklearn): 130519212.48902301

# %%
print(y_sklearn_pred)
# Out:
# [44680.43395816 46880.23797858 44849.64965204 44511.21826428
#  45526.51242755 43834.35548877 43157.49271325 44342.0025704
#  46372.59089695 42819.0613255  45864.94381531 45695.72812143
#  45526.51242755 44849.64965204 48064.74783573 45018.86534592
#  42311.41424386 44172.78687652 45695.72812143 43665.13979489
#  47387.88506022 43326.70840713 43326.70840713 42311.41424386
#  47557.1007541  48572.39491737 47557.1007541  45188.0810398
#  43495.92410101 45357.29673367 45188.0810398  44342.0025704
#  47049.45367246 42311.41424386 48403.17922349 44680.43395816
#  48572.39491737 44680.43395816 48064.74783573 47726.31644797
#  42142.19854998 44680.43395816 45695.72812143 47557.1007541
#  43326.70840713 42819.0613255  46372.59089695 45357.29673367
#  44172.78687652 47218.66936634 47049.45367246 44849.64965204
#  47557.1007541  47387.88506022 43157.49271325 47049.45367246
#  48233.96352961 45018.86534592 43665.13979489 42988.27701937]
